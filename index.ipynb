# %%
import pandas as pd

link = "https://github.com/CienciaDeDatosEspacial/code_and_data/raw/main/data/carbonEmi_downloaded.csv"
carbon = pd.read_csv(link)
carbon
# Out:
#                                               name  \
# 0                                            China
# 1                                    United States
# 2                                            India
# 3                                           Russia
# 4                                            Japan
# ..                                             ...
# 213                                     Antarctica
# 214  Saint Helena, Ascension, and Tristan da Cunha
# 215                                           Niue
# 216                       Northern Mariana Islands
# 217                                         Tuvalu
#
#                                             slug             value  \
# 0                                          china  10,773,248,000.0
# 1                                  united-states   5,144,361,000.0
# 2                                          india   2,314,738,000.0
# 3                                         russia   1,848,070,000.0
# ...

# %% [markdown]
# ### 1. Keep the columns name, value, date_of_information and region

# %%
carbon.columns
# Out:
# Index(['name', 'slug', 'value', 'date_of_information', 'ranking', 'region'], dtype='object')

# %%
byecolumns = {'name', 'slug', 'value', 'date_of_information', 'ranking', 'region'} - {'name', 'value', 'date_of_information', 'region'}

link = "https://github.com/CienciaDeDatosEspacial/code_and_data/raw/main/data/carbonEmi_downloaded.csv"
carbon = pd.read_csv(link)

carbonCleaned = carbon.drop(columns = byecolumns)
carbonCleaned
# Out:
#                                               name             value  \
# 0                                            China  10,773,248,000.0
# 1                                    United States   5,144,361,000.0
# 2                                            India   2,314,738,000.0
# 3                                           Russia   1,848,070,000.0
# 4                                            Japan   1,103,234,000.0
# ..                                             ...               ...
# 213                                     Antarctica          28,000.0
# 214  Saint Helena, Ascension, and Tristan da Cunha          13,000.0
# 215                                           Niue           8,000.0
# 216                       Northern Mariana Islands               0.0
# 217                                         Tuvalu               0.0
#
#     date_of_information                   region
# 0             2019 est.  East and Southeast Asia
# ...

# %% [markdown]
# ### 2. Change the column name date_of_information to carbon_date

# %%
link = "https://github.com/CienciaDeDatosEspacial/code_and_data/raw/main/data/carbonEmi_downloaded.csv"
carbon = pd.read_csv(link)

carbonCleaned = carbon.drop(columns = byecolumns)
carbonCleaned.rename(columns={"date_of_information" : "carbon_date"}, inplace=True)
carbonCleaned
# Out:
#                                               name             value  \
# 0                                            China  10,773,248,000.0
# 1                                    United States   5,144,361,000.0
# 2                                            India   2,314,738,000.0
# 3                                           Russia   1,848,070,000.0
# 4                                            Japan   1,103,234,000.0
# ..                                             ...               ...
# 213                                     Antarctica          28,000.0
# 214  Saint Helena, Ascension, and Tristan da Cunha          13,000.0
# 215                                           Niue           8,000.0
# 216                       Northern Mariana Islands               0.0
# 217                                         Tuvalu               0.0
#
#     carbon_date                   region
# 0     2019 est.  East and Southeast Asia
# 1     2019 est.            North America
# ...

# %% [markdown]
# ### 3. Make sure the cells with text does not have neither trailing nor leading spaces.

# %%
carbonCleaned.columns
# Out:
# Index(['name', 'value', 'carbon_date', 'region'], dtype='object')

# %%
carbon = pd.read_csv(link)
name = carbonCleaned.name.str.contains(pat='r\^s|\s$',regex=True)
value = carbonCleaned.name.str.contains(pat='r\^s|\s$',regex=True)
carbon_date = carbonCleaned.carbon_date.str.contains(pat='r\^s|\s$',regex=True)
region = carbonCleaned.region.str.contains(pat='r\^s|\s$',regex=True)
espacios = {"name":name, "value" : value, "carbon_date": carbon_date,"region": region}

espacios = pd.DataFrame(espacios)
espacios
# Out:
#       name  value  carbon_date  region
# 0    False  False        False   False
# 1    False  False        False   False
# 2    False  False        False   False
# 3    False  False        False   False
# 4    False  False        False   False
# ..     ...    ...          ...     ...
# 213  False  False        False   False
# 214  False  False        False   False
# 215  False  False        False   False
# 216  False  False        False   False
# 217  False  False        False   False
#
# [218 rows x 4 columns]

# %% [markdown]
# ### 4. Detect the presence of symbols in the numeric data that are not numeric or point.

# %%
value = carbonCleaned.name.str.contains(pat=r'[\D|~"."]', regex=True)
carbon_date = carbonCleaned.carbon_date.str.contains(pat=r'[\D|~"."]', regex=True)
DatosNoNumericosOPunto = { "value" : value, "carbon_date": carbon_date}

DatosNoNumericosOPunto  = pd.DataFrame(DatosNoNumericosOPunto)
DatosNoNumericosOPunto
# Out:
#      value  carbon_date
# 0     True         True
# 1     True         True
# 2     True         True
# 3     True         True
# 4     True         True
# ..     ...          ...
# 213   True         True
# 214   True         True
# 215   True         True
# 216   True         True
# 217   True         True
#
# [218 rows x 2 columns]

# %% [markdown]
# #### 4.a) Eliminar elementos no numéricos o puntos de la columna "value"

# %%
carbonCleaned.loc[:,["value"]]
# Out:
#                 value
# 0    10,773,248,000.0
# 1     5,144,361,000.0
# 2     2,314,738,000.0
# 3     1,848,070,000.0
# 4     1,103,234,000.0
# ..                ...
# 213          28,000.0
# 214          13,000.0
# 215           8,000.0
# 216               0.0
# 217               0.0
#
# [218 rows x 1 columns]

# %%
link = "https://github.com/CienciaDeDatosEspacial/code_and_data/raw/main/data/carbonEmi_downloaded.csv"
carbon = pd.read_csv(link)
carbonCleaned = carbon.drop(columns = byecolumns)
carbonCleaned.rename(columns={"date_of_information" : "carbon_date"}, inplace=True)

import re
ByeCommas = lambda x: float(re.sub('[","|\s]',"",x))

carbonCleaned["value"]=carbonCleaned.loc[:,["value"]].applymap(ByeCommas)
carbonCleaned.loc[:,["value"]]
# Out:
#             value
# 0    1.077325e+10
# 1    5.144361e+09
# 2    2.314738e+09
# 3    1.848070e+09
# 4    1.103234e+09
# ..            ...
# 213  2.800000e+04
# 214  1.300000e+04
# 215  8.000000e+03
# 216  0.000000e+00
# 217  0.000000e+00
#
# [218 rows x 1 columns]

# %% [markdown]
# #### 4.b) Eliminar elementos no numéricos o puntos de la columna "carbon_date"

# %%
link = "https://github.com/CienciaDeDatosEspacial/code_and_data/raw/main/data/carbonEmi_downloaded.csv"
carbon = pd.read_csv(link)
carbonCleaned = carbon.drop(columns = byecolumns)
carbonCleaned.rename(columns={"date_of_information" : "carbon_date"}, inplace=True)
carbonCleaned["value"]=carbonCleaned.loc[:,["value"]].applymap(ByeCommas)
carbonCleaned.loc[:,["value"]]

carbonCleaned.loc[:,"carbon_date"]
# Out:
# 0      2019 est.
# 1      2019 est.
# 2      2019 est.
# 3      2019 est.
# 4      2019 est.
#          ...
# 213    2019 est.
# 214    2019 est.
# 215    2019 est.
# 216    2019 est.
# 217    2019 est.
# Name: carbon_date, Length: 218, dtype: object

# %%
carbonCleaned.loc[:,"carbon_date"]=carbonCleaned.carbon_date.str.replace(pat=r'[\D & ~"."&\s]',repl="",regex=True)
carbonCleaned
# Out:
#                                               name         value carbon_date  \
# 0                                            China  1.077325e+10        2019
# 1                                    United States  5.144361e+09        2019
# 2                                            India  2.314738e+09        2019
# 3                                           Russia  1.848070e+09        2019
# 4                                            Japan  1.103234e+09        2019
# ..                                             ...           ...         ...
# 213                                     Antarctica  2.800000e+04        2019
# 214  Saint Helena, Ascension, and Tristan da Cunha  1.300000e+04        2019
# 215                                           Niue  8.000000e+03        2019
# 216                       Northern Mariana Islands  0.000000e+00        2019
# 217                                         Tuvalu  0.000000e+00        2019
#
#                       region
# ...

# %% [markdown]
# ### 5. Make sure there are no spaces as part of the column names.

# %%
carbonCleaned.columns.str.contains(pat=r'\s',regex=True)
# Out:
# array([False, False, False, False])

# %% [markdown]
# ### 6. Get rid of any value detected in the previous step:

# %%
carbonCleaned.columns.str.replace(pat=r'\s', repl="",regex=True)
carbonCleaned.columns
# Out:
# Index(['name', 'value', 'carbon_date', 'region'], dtype='object')

# %% [markdown]
# ### 7. Keep only the year value in the column carbon_date.

# %% [markdown]
# Ya se eliminaron los " est." en el apartado 4b.

# %%
#Tabla final
carbonCleaned
# Out:
#                                               name         value carbon_date  \
# 0                                            China  1.077325e+10        2019
# 1                                    United States  5.144361e+09        2019
# 2                                            India  2.314738e+09        2019
# 3                                           Russia  1.848070e+09        2019
# 4                                            Japan  1.103234e+09        2019
# ..                                             ...           ...         ...
# 213                                     Antarctica  2.800000e+04        2019
# 214  Saint Helena, Ascension, and Tristan da Cunha  1.300000e+04        2019
# 215                                           Niue  8.000000e+03        2019
# 216                       Northern Mariana Islands  0.000000e+00        2019
# 217                                         Tuvalu  0.000000e+00        2019
#
#                       region
# ...

# %% [markdown]
# #####  When all tasks are done, save the cleaned file inside your **data** folder:

# %%
import os

carbonCleaned.to_csv("carbonCleaned.csv")
