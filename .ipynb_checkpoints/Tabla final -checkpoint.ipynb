# %%
import pandas as pd

linkGH= "https://github.com/Ciencia-de-datos-espaciales-2023-2/S4_LimpiezaDeDatos_Ejercicio1/raw/main/carbonCleaned.csv"
carbonCleaned = pd.read_csv(linkGH)
carbonCleaned
# Out:
#      Unnamed: 0                                           name         value  \
# 0             0                                          China  1.077325e+10
# 1             1                                  United States  5.144361e+09
# 2             2                                          India  2.314738e+09
# 3             3                                         Russia  1.848070e+09
# 4             4                                          Japan  1.103234e+09
# ..          ...                                            ...           ...
# 213         213                                     Antarctica  2.800000e+04
# 214         214  Saint Helena, Ascension, and Tristan da Cunha  1.300000e+04
# 215         215                                           Niue  8.000000e+03
# 216         216                       Northern Mariana Islands  0.000000e+00
# 217         217                                         Tuvalu  0.000000e+00
#
#      carbon_date                   region
# ...
